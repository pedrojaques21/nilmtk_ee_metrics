# %%
import compress_pickle as cp

# %%
# specify the path of the compressed file
ff = cp.load('./experiments/NILMTK/CO/FF/CO_4_FF.gz')
fr = cp.load('./experiments/NILMTK/CO/FR/CO_4_FR.gz')
fz = cp.load('./experiments/NILMTK/CO/FZ/CO_4_FZ.gz')

# %%
print(ff.appliances)
print(fr.appliances)
print(fz.appliances)
# Out:
# ['fridge freezer']
# ['fridge']
# ['freezer']

# %%
data.pred_overall.get('RNN').plot()

# %%
data.train_mains[0].plot()

# %%
data.train_submeters[0][1][0].plot()

# %%
data.test_mains[0].plot()

# %%
data.test_submeters[0][1][0].plot()

# %%
new = cp.load('./metrics/ee_metrics_x_experiments_df_NEW.gz')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 new = cp.load('./metrics/ee_metrics_x_experiments_df_NEW.gz')
#
# File ~\.conda\envs\deep-nilmtk\lib\site-packages\compress_pickle\compress_pickle.py:272, in load(path, compression, pickler_method, pickler_kwargs, mode, set_default_extension, **kwargs)
#     270     pickler_kwargs = {}
#     271 try:
# --> 272     output = uncompress_and_unpickle(
#     273         compresser,
#     274         pickler=pickler,
#     275         **pickler_kwargs,
#     276     )
#     277 finally:
#     278     compresser.close()
#
# File ~\.conda\envs\deep-nilmtk\lib\functools.py:875, in singledispatch.<locals>.wrapper(*args, **kw)
#     871 if not args:
#     872     raise TypeError(f'{funcname} requires at least '
#     873                     '1 positional argument')
# ...
